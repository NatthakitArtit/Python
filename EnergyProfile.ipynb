# %%
import matplotlib.pyplot as plt
from energydiagram import ED
diagram = ED()
diagram.add_level(-12.6,'HBA')
diagram.add_level(0,'','l',color='r')
diagram.add_level(5.5,'TS\u2081')
diagram.add_level(13.0,'','l',color='r')
diagram.add_level(-7.2,'INT') #Using 'last'  or 'l' it will be together with the previous level
diagram.add_level(0.0,'','l',color='r')
diagram.add_level(9.8,'TS\u2082')
diagram.add_level(28.6,'','l',color='r')
diagram.add_level(-34.8,'PROD')
diagram.add_level(-28.8,'','l',color='r')

diagram.add_link(0,2)
diagram.add_link(2,4)
diagram.add_link(4,6)
diagram.add_link(6,8)

diagram.add_link(1,3,color='r')
diagram.add_link(3,5,color='r')
diagram.add_link(5,7,color='r')
diagram.add_link(7,9,color='r')

diagram.plot(ylabel="Energy / $kcal$ $mol^{-1}$") # this is the default ylabel
plt.savefig('EnergyProfile.png')
